# %%
from src.data_processing.text_cleaner import clean_text

sample_text = "Python Developer with Machine Learning skills!"
clean_text(sample_text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.data_processing.text_cleaner import clean_text
#       3 sample_text = "Python Developer with Machine Learning skills!"
#       4 clean_text(sample_text)
#
# ModuleNotFoundError: No module named 'src'
