# %%
# Ensure src is importable when running notebooks
import sys, os
PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

print("Setup complete. Project root added.")
# Out:
# Setup complete. Project root added.

# %%
# !pip install PyPDF2 python-docx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.1 MB 3.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.0/4.1 MB 2.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.8/4.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------- -------------- 2.6/4.1 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.7/4.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 3.4 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/3 [PyPDF2]
#    ---------------------------------------- 0/3 [PyPDF2]
#    ---------------------------------------- 0/3 [PyPDF2]
#    ---------------------------------------- 0/3 [PyPDF2]
#    ---------------------------------------- 0/3 [PyPDF2]
#    ------------- -------------------------- 1/3 [lxml]
# ...

# %%
import os
from src.data_processing.resume_parser import parse_resume

resume_dir = "../data/raw/resumes"

for file in os.listdir(resume_dir):
    print(f"\n--- {file} ---")
    print(parse_resume(os.path.join(resume_dir, file))[:200])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 import os
# ----> 2 from src.data_processing.resume_parser import parse_resume
#       4 resume_dir = "../data/raw/resumes"
#       6 for file in os.listdir(resume_dir):
#
# File c:\Users\LENOVO\OneDrive\Desktop\resume-screening-system\src\data_processing\resume_parser.py:2
#       1 import os
# ----> 2 from PyPDF2 import PdfReader
#       3 from docx import Document
#       5 def parse_resume(file_path):
#
# ModuleNotFoundError: No module named 'PyPDF2'
